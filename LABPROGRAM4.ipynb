# %%
import numpy as np
X = np.array(([2,9],[1,5],[3,6]),dtype=float)
y = np.array(([92],[86],[89]),dtype=float)
X=X/np.amax(X,axis=0)
y=y/100
def sigmoid(x):
    return 1/(1+np.exp(-x))
def derivatives_sigmoid(x):
    return x*(1-x)
epoch=20
learning_rate=0.1
inputlayer_neurons=2
hiddenlayer_neurons=3
outputlayer_neurons=1
wh=np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))
bh=np.random.uniform(size=(1,hiddenlayer_neurons))
wo=np.random.uniform(size=(hiddenlayer_neurons,outputlayer_neurons))
bo=np.random.uniform(size=(1,outputlayer_neurons))
for i in range(epoch):
    net_h=np.dot(X,wh)+bh
   
    sigma_h=sigmoid(net_h)
    net_o=np.dot(sigma_h,wo)+bo
    output=sigmoid(net_o)
   
    deltaK=(y-output)*derivatives_sigmoid(output)
    deltaH=deltaK.dot(wo.T)*derivatives_sigmoid(sigma_h)
   
    wo=wo+sigma_h.T.dot(deltaK)*learning_rate
    wh=wh+X.T.dot(deltaH)*learning_rate
   
    error=sum(deltaK)**2/len(deltaK)
   
    print('Epoch -> {0}, lrate -> {1}, error -> {2}'.format(i,learning_rate,error))
# Out:
# Epoch -> 0, lrate -> 0.1, error -> [0.00058818]
# Epoch -> 1, lrate -> 0.1, error -> [0.00056795]
# Epoch -> 2, lrate -> 0.1, error -> [0.0005486]
# Epoch -> 3, lrate -> 0.1, error -> [0.00053008]
# Epoch -> 4, lrate -> 0.1, error -> [0.00051235]
# Epoch -> 5, lrate -> 0.1, error -> [0.00049537]
# Epoch -> 6, lrate -> 0.1, error -> [0.0004791]
# Epoch -> 7, lrate -> 0.1, error -> [0.0004635]
# Epoch -> 8, lrate -> 0.1, error -> [0.00044855]
# Epoch -> 9, lrate -> 0.1, error -> [0.0004342]
# Epoch -> 10, lrate -> 0.1, error -> [0.00042044]
# Epoch -> 11, lrate -> 0.1, error -> [0.00040722]
# Epoch -> 12, lrate -> 0.1, error -> [0.00039452]
# Epoch -> 13, lrate -> 0.1, error -> [0.00038233]
# Epoch -> 14, lrate -> 0.1, error -> [0.00037061]
# Epoch -> 15, lrate -> 0.1, error -> [0.00035934]
# Epoch -> 16, lrate -> 0.1, error -> [0.0003485]
# Epoch -> 17, lrate -> 0.1, error -> [0.00033807]
# Epoch -> 18, lrate -> 0.1, error -> [0.00032804]
# Epoch -> 19, lrate -> 0.1, error -> [0.00031837]

# %%
print("Input:\n"+str(X))
# Out:
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]

# %%
print("Actual Output:\n"+str(y))
# Out:
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]

# %%
print("Predicted Output:\n",output)
# Out:
# Predicted Output:
#  [[0.82587392]
#  [0.81007469]
#  [0.8233816 ]]
